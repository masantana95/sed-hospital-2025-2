# %%
import random
import simpy

# Cria environment
random.seed(1000)
env = simpy.Environment()   # Necessário para criar o ambiente (environment) do modelo
                            # Possui um relógio central que avança conforme os enventos ocorrem, além de controlar o momento que os eventos devem ocorrer

# Criação dos recursos
auxiliar_adm = simpy.Resource(env, capacity=1)
medico = simpy.Resource(env, capacity = 1)
equipe_enfermagem = simpy.Resource(env, capacity = 1)
tecnico_enfermagem = simpy.Resource(env, capacity = 1)

def distribuicoes(tipo):
    return {
            # Tempos de processo
            'dist_organizar_pedido' : random.triangular(1,5,3),
            'dist_avaliar_prioridade' : random.triangular(1,5,3),
            'dist_agendar_exame' : random.triangular(1,5,3),
            'dist_informar_pre_requisito' : random.triangular(1,5,3),
            'dist_preparar_paciente' : random.triangular(1,5,3),
            'dist_transportar_paciente' : random.triangular(1,5,3),
            'dist_avaliacao_de_realizacao_de_exame' : random.triangular(1,5,3),
            'dist_avaliacao_exame_pode_ser_no_hospital' : random.triangular(1,5,3),
            'dist_realizacao_do_exame_fora_do_hospital' : random.triangular(1,5,3),
            'dist_realizacao_do_exame_no_hospital' : random.triangular(1,5,3),
            'dist_retorno_paciente' : random.triangular(1,5,3),
            'dist_atualizar_mv' : random.triangular(1,5,3),
            'dist_analisar_exame_urgente' : random.triangular(1,5,3) * 0.3,
            'dist_analisar_exame_nao_urgente' : random.triangular(1,5,3)
    }.get(tipo,0.0)

# Porcentagens de decisão
x = 0.3 # Porcentagem dos exames que são urgentes
y = 0.3 # Porcentagem de pacientes que precisam ser reagendados devido a não estarem preparados para o exame
z = 0.3 # Porcentagem de exames que devem ser feitos fora do hospital

# Outros parâmetros
limite_preparacao_exame = 3 # Número máximo de vezes que o paciente percorre o loop de preparação para exames, afim de evitar loopings infinitos
def AtividadeCom1RecursoExame(env,exame,nome_da_atividade,recurso,tempo_atividade):
    # String comum para informar que o recurso chegou
    print("Exame %s chega na atividade '%s' em %.2f" % (exame,nome_da_atividade, env.now))

    # Solicia o recurso. Isso singifica que a entidade entrou na fila para usá-lo.
    requisicao = recurso.request()

    # Aguarda em fila para uso do recurso
    tempo_inicio_fila = env.now
    yield requisicao
    tempo_em_fila = env.now - tempo_inicio_fila
    
    # Atividade ocorre
    print("Exame %s inicia a atividade '%s' em %.2f (Tempo em fila = %.2f)" % (exame,nome_da_atividade, env.now,tempo_em_fila))
    yield env.timeout(tempo_atividade)

    # Libera o recurso
    yield recurso.release(requisicao)
    print("Exame %s na atividade '%s' finalizado em %.2f" % (exame,nome_da_atividade, env.now))

def AtividadeCom1RecursoPaciente(env,exame,nome_da_atividade,recurso,tempo_atividade):
    # String comum para informar que o recurso chegou
    print("Paciente do exame %s chega na atividade '%s' em %.2f" % (exame,nome_da_atividade, env.now))

    # Solicia o recurso. Isso singifica que a entidade entrou na fila para usá-lo.
    requisicao = recurso.request()

    # Aguarda em fila para uso do recurso
    tempo_inicio_fila = env.now
    yield requisicao
    tempo_em_fila = env.now - tempo_inicio_fila
    
    # Atividade ocorre
    print("Paciente do exame %s inicia a atividade '%s' em %.2f (Tempo em fila = %.2f)" % (exame,nome_da_atividade, env.now,tempo_em_fila))
    yield env.timeout(tempo_atividade)

    # Libera o recurso
    yield recurso.release(requisicao)
    print("Paciente do exame %s na atividade '%s' finalizado em %.2f" % (exame,nome_da_atividade, env.now))

def AtividadeSemRecurso(env, exame, nome_da_atividade, tempo_atividade):
    "Para atividades que consomem tempo mas não usam recursos"
    print("Exame %s chega na atividade '%s' em %.2f" % (exame, nome_da_atividade, env.now))
    print("Exame %s inicia a atividade '%s' em %.2f" % (exame, nome_da_atividade, env.now))
    
    yield env.timeout(tempo_atividade)  # Apenas consome tempo
    
    print("Exame %s na atividade '%s' finalizado em %.2f" % (exame, nome_da_atividade, env.now))

# Chegada dos exames
def geraChegadasExames(env, taxa_exames):
    contaChegadaExame = 0
    while True:
        yield env.timeout(random.expovariate(1/taxa_exames)) # Cria tempos de acordo com uma distribuição de probabilidade
        contaChegadaExame += 1
        print("Exame %s chega no sistema em: %.2f " % (contaChegadaExame,env.now))
        env.process(procExames(env, contaChegadaExame, auxiliar_adm, medico,equipe_enfermagem,tecnico_enfermagem)) 

# Processo de um exame
def procExames(env, exame, auxiliar_adm, medico, equipe_enfermagem,tecnico_enfermagem):
    # Atributos do exame
    Prob_Urgencia = random.uniform(0,1)
    if Prob_Urgencia <= x: #Exame urgente
        A_urgencia = 1 
    else:
        A_urgencia = 0

    # Instante de início do processo
    instante_inicio_processo = env.now
    # Atividades
    # Atividade 1 - Organizar pedidos
    nome_da_atividade = "1 - Organizar pedidos"
    yield from AtividadeCom1RecursoExame(env,exame,nome_da_atividade,auxiliar_adm,distribuicoes('dist_organizar_pedido'))
    #############################################################################################
    # Atividade 2 - Avaliar prioridade
    nome_da_atividade = "2 - Avaliar prioridade"
    yield from AtividadeCom1RecursoExame(env,exame,nome_da_atividade,medico,distribuicoes('dist_avaliar_prioridade'))
    #############################################################################################
    if A_urgencia == 1:
        print("Exame urgente!!!")
        # Atividades 4,5,6 e 7
        procPreRealizacaoExames(env, exame, equipe_enfermagem, tecnico_enfermagem)
    else:
        # Atividade 3 - Informar pré-requisitos
        print("Exame não urgente")
        nome_da_atividade = "3 - Agendar exame"
        yield from AtividadeCom1RecursoExame(env,exame,nome_da_atividade,auxiliar_adm,distribuicoes('dist_agendar_exame'))   
        # Seguir loop de pré-realização dos exames
        # Atividades 4,5,6 e 7
        procPreRealizacaoExames(env, exame, equipe_enfermagem, tecnico_enfermagem)     
    #############################################################################################
    # Sorteia se o paciente está preparado (1) ou não (0)
    if random.random() > y:
        paciente_preparado = 1
    else:
        paciente_preparado = 0
    
    passagem_no_loop = 0
    while paciente_preparado == 0 and passagem_no_loop < limite_preparacao_exame:
        nome_da_atividade = "3 - Agendar exame" # Será que não deveria ser ponderado se o exame é urgente ou não?
        print("Reagendamento do exame %s por paciente não estar preparado" % (exame))
        yield from AtividadeCom1RecursoExame(env,exame,nome_da_atividade,auxiliar_adm,distribuicoes('dist_agendar_exame'))
        # Atividades 4,5,6 e 7 novamente
        procPreRealizacaoExames(env, exame, equipe_enfermagem, tecnico_enfermagem) 
        passagem_no_loop += 1 # Para evitar loops infinitos
        # Sorteia novamente se o paciente está preparado (1) ou não (0)
        if random.random() > y:
            paciente_preparado = 1
        else:
            paciente_preparado = 0
    #############################################################################################
    # Atividade 8 - Avaliar se exame pode ser feito no hospital
    nome_da_atividade = "8 - Avaliar se exame pode ser feito no hospital"
    yield from AtividadeSemRecurso(env,exame,nome_da_atividade,distribuicoes('dist_avaliacao_exame_pode_ser_no_hospital'))
    #############################################################################################
    # Sorteia se exame pode ou não ser feito no hospital
    if random.random() <= z:
        exame_fora_do_hospital = 1
    else:
        exame_fora_do_hospital = 0
    if exame_fora_do_hospital == 1:
        # Atividade 9 - Realizar exame fora do hospital
        nome_da_atividade = "9 - Realizar exame fora do hospital"
        yield from AtividadeSemRecurso(env,exame,nome_da_atividade,distribuicoes('dist_realizacao_do_exame_fora_do_hospital'))
    else:
         # Atividade 10 - Realizar exame no hospital
        nome_da_atividade = "10 - Realizar exame no hospital"
        yield from AtividadeCom1RecursoExame(env,exame,nome_da_atividade,equipe_enfermagem,distribuicoes('dist_realizacao_do_exame_no_hospital'))
        env.process(procRetornoPaciente(env,exame,equipe_enfermagem))

    #############################################################################################
    # Atividade 11 - Atualizar MV
    nome_da_atividade = "11 - Atualizar MV"
    yield from AtividadeSemRecurso(env,exame,nome_da_atividade,distribuicoes('dist_realizacao_do_exame_fora_do_hospital'))
    #############################################################################################
    if A_urgencia == 1:
        # Atividade 13 - Analisar exame urgente
        nome_da_atividade = "13 - Analisar exame urgente"
        yield from AtividadeSemRecurso(env,exame,nome_da_atividade,distribuicoes('dist_analisar_exame_urgente'))
    else:
        # Atividade 14 - Analisar exame não urgente
        nome_da_atividade = "14 - Analisar exame não urgente"
        yield from AtividadeSemRecurso(env,exame,nome_da_atividade,distribuicoes('dist_analisar_exame_nao_urgente'))

    instante_final_do_processo = env.now
    duracao_do_processo = instante_final_do_processo - instante_inicio_processo
    print("Fim do processo do exame %s, no instante %.2f. Duração total = %.2f" %(exame, instante_final_do_processo,duracao_do_processo))


def procPreRealizacaoExames(env, exame, equipe_enfermagem, tecnico_enfermagem):
    # Processo que vai da informação do pré-requisito dos exames até a avaliação se o paciente pode realizar o exame
    # Atividade 4 - Informar pré-requisitos
    nome_da_atividade = "4 - Informar pré-requisitos"
    yield from AtividadeCom1RecursoExame(env,exame,nome_da_atividade,equipe_enfermagem,distribuicoes('dist_informar_pre_requisito')) 
    #############################################################################################
    # Atividade 5 - Preparar Paciente
    nome_da_atividade = "5 - Preparar paciente"
    yield from AtividadeCom1RecursoExame(env,exame,nome_da_atividade,equipe_enfermagem,distribuicoes('dist_preparar_paciente'))
    #############################################################################################
    # Atividade 6 - Transportar paciente
    nome_da_atividade = "6 - Transportar paciente"
    yield from AtividadeCom1RecursoExame(env,exame,nome_da_atividade,tecnico_enfermagem,distribuicoes('dist_transportar_paciente'))
    #############################################################################################
    # Atividade 7 - Avaliação de realização de exame
    nome_da_atividade = "7 - Avaliação de realização de exame"
    yield from AtividadeSemRecurso(env,exame,nome_da_atividade,distribuicoes('dist_atualizar_mv'))

def procRetornoPaciente(env,exame,equipe_enfermagem):
    # Atividade 12 - Retorno do paciente ao PS
    nome_da_atividade = "Atividade 12 - Retorno do paciente ao PS"
    yield from AtividadeCom1RecursoPaciente(env,exame,nome_da_atividade,equipe_enfermagem,distribuicoes('dist_retorno_paciente'))


taxa_de_chegada_exames = 10 # Chegada de exames por minuto
env.process(geraChegadasExames(env,taxa_de_chegada_exames))
# Roda a simulação por unidades de tempo determinadas. Notar que não há unidade de tempo pré definida por sistema
tempo_de_rodada = 100
env.run(until=tempo_de_rodada)
# Out:
# Exame 1 chega no sistema em: 15.02
# Exame 1 chega na atividade '1 - Organizar pedidos' em 15.02
# Exame 1 inicia a atividade '1 - Organizar pedidos' em 15.02 (Tempo em fila = 0.00)
# Exame 1 na atividade '1 - Organizar pedidos' finalizado em 17.70
# Exame 1 chega na atividade '2 - Avaliar prioridade' em 17.70
# Exame 1 inicia a atividade '2 - Avaliar prioridade' em 17.70 (Tempo em fila = 0.00)
# Exame 1 na atividade '2 - Avaliar prioridade' finalizado em 20.62
# Exame urgente!!!
# Reagendamento do exame 1 por paciente não estar preparado
# Exame 1 chega na atividade '3 - Agendar exame' em 20.62
# Exame 1 inicia a atividade '3 - Agendar exame' em 20.62 (Tempo em fila = 0.00)
# Exame 1 na atividade '3 - Agendar exame' finalizado em 21.99
# Exame 1 chega na atividade '8 - Avaliar se exame pode ser feito no hospital' em 21.99
# Exame 1 inicia a atividade '8 - Avaliar se exame pode ser feito no hospital' em 21.99
# Exame 1 na atividade '8 - Avaliar se exame pode ser feito no hospital' finalizado em 24.06
# Exame 1 chega na atividade '9 - Realizar exame fora do hospital' em 24.06
# Exame 1 inicia a atividade '9 - Realizar exame fora do hospital' em 24.06
# Exame 2 chega no sistema em: 26.10
# Exame 2 chega na atividade '1 - Organizar pedidos' em 26.10
# Exame 2 inicia a atividade '1 - Organizar pedidos' em 26.10 (Tempo em fila = 0.00)
# Exame 1 na atividade '9 - Realizar exame fora do hospital' finalizado em 26.33
# Exame 1 chega na atividade '11 - Atualizar MV' em 26.33
# Exame 1 inicia a atividade '11 - Atualizar MV' em 26.33
# Exame 2 na atividade '1 - Organizar pedidos' finalizado em 28.92
# Exame 2 chega na atividade '2 - Avaliar prioridade' em 28.92
# Exame 2 inicia a atividade '2 - Avaliar prioridade' em 28.92 (Tempo em fila = 0.00)
# Exame 1 na atividade '11 - Atualizar MV' finalizado em 29.85
# Exame 1 chega na atividade '13 - Analisar exame urgente' em 29.85
# Exame 1 inicia a atividade '13 - Analisar exame urgente' em 29.85
# Exame 1 na atividade '13 - Analisar exame urgente' finalizado em 31.32
# Fim do processo do exame 1, no instante 31.32. Duração total = 16.30
# Exame 2 na atividade '2 - Avaliar prioridade' finalizado em 31.90
# Exame não urgente
# Exame 2 chega na atividade '3 - Agendar exame' em 31.90
# Exame 2 inicia a atividade '3 - Agendar exame' em 31.90 (Tempo em fila = 0.00)
# Exame 2 na atividade '3 - Agendar exame' finalizado em 35.87
# Reagendamento do exame 2 por paciente não estar preparado
# Exame 2 chega na atividade '3 - Agendar exame' em 35.87
# Exame 2 inicia a atividade '3 - Agendar exame' em 35.87 (Tempo em fila = 0.00)
# Exame 2 na atividade '3 - Agendar exame' finalizado em 39.38
# Reagendamento do exame 2 por paciente não estar preparado
# Exame 2 chega na atividade '3 - Agendar exame' em 39.38
# Exame 2 inicia a atividade '3 - Agendar exame' em 39.38 (Tempo em fila = 0.00)
# Exame 2 na atividade '3 - Agendar exame' finalizado em 41.89
# Exame 2 chega na atividade '8 - Avaliar se exame pode ser feito no hospital' em 41.89
# Exame 2 inicia a atividade '8 - Avaliar se exame pode ser feito no hospital' em 41.89
# Exame 2 na atividade '8 - Avaliar se exame pode ser feito no hospital' finalizado em 45.36
# Exame 2 chega na atividade '10 - Realizar exame no hospital' em 45.36
# Exame 2 inicia a atividade '10 - Realizar exame no hospital' em 45.36 (Tempo em fila = 0.00)
# Exame 3 chega no sistema em: 48.40
# Exame 3 chega na atividade '1 - Organizar pedidos' em 48.40
# Exame 3 inicia a atividade '1 - Organizar pedidos' em 48.40 (Tempo em fila = 0.00)
# Exame 2 na atividade '10 - Realizar exame no hospital' finalizado em 48.92
# Exame 2 chega na atividade '11 - Atualizar MV' em 48.92
# Exame 2 inicia a atividade '11 - Atualizar MV' em 48.92
# Paciente do exame 2 chega na atividade 'Atividade 12 - Retorno do paciente ao PS' em 48.92
# Paciente do exame 2 inicia a atividade 'Atividade 12 - Retorno do paciente ao PS' em 48.92 (Tempo em fila = 0.00)
# Exame 2 na atividade '11 - Atualizar MV' finalizado em 51.77
# Exame 2 chega na atividade '14 - Analisar exame não urgente' em 51.77
# Exame 2 inicia a atividade '14 - Analisar exame não urgente' em 51.77
# Exame 3 na atividade '1 - Organizar pedidos' finalizado em 51.88
# Exame 3 chega na atividade '2 - Avaliar prioridade' em 51.88
# Exame 3 inicia a atividade '2 - Avaliar prioridade' em 51.88 (Tempo em fila = 0.00)
# Paciente do exame 2 na atividade 'Atividade 12 - Retorno do paciente ao PS' finalizado em 52.27
# Exame 3 na atividade '2 - Avaliar prioridade' finalizado em 53.76
# Exame não urgente
# Exame 3 chega na atividade '3 - Agendar exame' em 53.76
# Exame 3 inicia a atividade '3 - Agendar exame' em 53.76 (Tempo em fila = 0.00)
# Exame 2 na atividade '14 - Analisar exame não urgente' finalizado em 56.09
# Fim do processo do exame 2, no instante 56.09. Duração total = 29.98
# Exame 3 na atividade '3 - Agendar exame' finalizado em 57.89
# Exame 3 chega na atividade '8 - Avaliar se exame pode ser feito no hospital' em 57.89
# Exame 3 inicia a atividade '8 - Avaliar se exame pode ser feito no hospital' em 57.89
# Exame 3 na atividade '8 - Avaliar se exame pode ser feito no hospital' finalizado em 61.52
# Exame 3 chega na atividade '10 - Realizar exame no hospital' em 61.52
# Exame 3 inicia a atividade '10 - Realizar exame no hospital' em 61.52 (Tempo em fila = 0.00)
# Exame 3 na atividade '10 - Realizar exame no hospital' finalizado em 64.56
# Exame 3 chega na atividade '11 - Atualizar MV' em 64.56
# Exame 3 inicia a atividade '11 - Atualizar MV' em 64.56
# Paciente do exame 3 chega na atividade 'Atividade 12 - Retorno do paciente ao PS' em 64.56
# Paciente do exame 3 inicia a atividade 'Atividade 12 - Retorno do paciente ao PS' em 64.56 (Tempo em fila = 0.00)
# Paciente do exame 3 na atividade 'Atividade 12 - Retorno do paciente ao PS' finalizado em 66.81
# Exame 4 chega no sistema em: 68.45
# Exame 4 chega na atividade '1 - Organizar pedidos' em 68.45
# Exame 4 inicia a atividade '1 - Organizar pedidos' em 68.45 (Tempo em fila = 0.00)
# Exame 3 na atividade '11 - Atualizar MV' finalizado em 69.25
# Exame 3 chega na atividade '14 - Analisar exame não urgente' em 69.25
# Exame 3 inicia a atividade '14 - Analisar exame não urgente' em 69.25
# Exame 5 chega no sistema em: 69.45
# Exame 5 chega na atividade '1 - Organizar pedidos' em 69.45
# Exame 3 na atividade '14 - Analisar exame não urgente' finalizado em 71.89
# Fim do processo do exame 3, no instante 71.89. Duração total = 23.48
# Exame 4 na atividade '1 - Organizar pedidos' finalizado em 72.16
# Exame 4 chega na atividade '2 - Avaliar prioridade' em 72.16
# Exame 5 inicia a atividade '1 - Organizar pedidos' em 72.16 (Tempo em fila = 2.70)
# Exame 4 inicia a atividade '2 - Avaliar prioridade' em 72.16 (Tempo em fila = 0.00)
# Exame 6 chega no sistema em: 72.95
# Exame 6 chega na atividade '1 - Organizar pedidos' em 72.95
# Exame 5 na atividade '1 - Organizar pedidos' finalizado em 75.06
# Exame 5 chega na atividade '2 - Avaliar prioridade' em 75.06
# Exame 6 inicia a atividade '1 - Organizar pedidos' em 75.06 (Tempo em fila = 2.11)
# Exame 4 na atividade '2 - Avaliar prioridade' finalizado em 75.69
# Exame urgente!!!
# Exame 4 chega na atividade '8 - Avaliar se exame pode ser feito no hospital' em 75.69
# Exame 4 inicia a atividade '8 - Avaliar se exame pode ser feito no hospital' em 75.69
# Exame 5 inicia a atividade '2 - Avaliar prioridade' em 75.69 (Tempo em fila = 0.64)
# Exame 6 na atividade '1 - Organizar pedidos' finalizado em 77.67
# Exame 6 chega na atividade '2 - Avaliar prioridade' em 77.67
# Exame 4 na atividade '8 - Avaliar se exame pode ser feito no hospital' finalizado em 77.78
# Exame 4 chega na atividade '10 - Realizar exame no hospital' em 77.78
# Exame 4 inicia a atividade '10 - Realizar exame no hospital' em 77.78 (Tempo em fila = 0.00)
# Exame 5 na atividade '2 - Avaliar prioridade' finalizado em 77.98
# Exame não urgente
# Exame 5 chega na atividade '3 - Agendar exame' em 77.98
# Exame 6 inicia a atividade '2 - Avaliar prioridade' em 77.98 (Tempo em fila = 0.30)
# Exame 5 inicia a atividade '3 - Agendar exame' em 77.98 (Tempo em fila = 0.00)
# Exame 5 na atividade '3 - Agendar exame' finalizado em 80.33
# Exame 5 chega na atividade '8 - Avaliar se exame pode ser feito no hospital' em 80.33
# Exame 5 inicia a atividade '8 - Avaliar se exame pode ser feito no hospital' em 80.33
# Exame 4 na atividade '10 - Realizar exame no hospital' finalizado em 80.81
# Exame 4 chega na atividade '11 - Atualizar MV' em 80.81
# Exame 4 inicia a atividade '11 - Atualizar MV' em 80.81
# Paciente do exame 4 chega na atividade 'Atividade 12 - Retorno do paciente ao PS' em 80.81
# Paciente do exame 4 inicia a atividade 'Atividade 12 - Retorno do paciente ao PS' em 80.81 (Tempo em fila = 0.00)
# Exame 6 na atividade '2 - Avaliar prioridade' finalizado em 82.02
# Exame não urgente
# Exame 6 chega na atividade '3 - Agendar exame' em 82.02
# Exame 6 inicia a atividade '3 - Agendar exame' em 82.02 (Tempo em fila = 0.00)
# Exame 5 na atividade '8 - Avaliar se exame pode ser feito no hospital' finalizado em 82.26
# Exame 5 chega na atividade '10 - Realizar exame no hospital' em 82.26
# Exame 7 chega no sistema em: 83.60
# Exame 7 chega na atividade '1 - Organizar pedidos' em 83.60
# Paciente do exame 4 na atividade 'Atividade 12 - Retorno do paciente ao PS' finalizado em 84.23
# Exame 5 inicia a atividade '10 - Realizar exame no hospital' em 84.23 (Tempo em fila = 1.97)
# Exame 4 na atividade '11 - Atualizar MV' finalizado em 84.33
# Exame 4 chega na atividade '13 - Analisar exame urgente' em 84.33
# Exame 4 inicia a atividade '13 - Analisar exame urgente' em 84.33
# Exame 4 na atividade '13 - Analisar exame urgente' finalizado em 85.01
# Fim do processo do exame 4, no instante 85.01. Duração total = 16.56
# Exame 6 na atividade '3 - Agendar exame' finalizado em 85.01
# Reagendamento do exame 6 por paciente não estar preparado
# Exame 6 chega na atividade '3 - Agendar exame' em 85.01
# Exame 7 inicia a atividade '1 - Organizar pedidos' em 85.01 (Tempo em fila = 1.41)
# Exame 5 na atividade '10 - Realizar exame no hospital' finalizado em 86.55
# Exame 5 chega na atividade '11 - Atualizar MV' em 86.55
# Exame 5 inicia a atividade '11 - Atualizar MV' em 86.55
# Paciente do exame 5 chega na atividade 'Atividade 12 - Retorno do paciente ao PS' em 86.55
# Paciente do exame 5 inicia a atividade 'Atividade 12 - Retorno do paciente ao PS' em 86.55 (Tempo em fila = 0.00)
# Paciente do exame 5 na atividade 'Atividade 12 - Retorno do paciente ao PS' finalizado em 87.90
# Exame 5 na atividade '11 - Atualizar MV' finalizado em 88.83
# Exame 5 chega na atividade '14 - Analisar exame não urgente' em 88.83
# Exame 5 inicia a atividade '14 - Analisar exame não urgente' em 88.83
# Exame 7 na atividade '1 - Organizar pedidos' finalizado em 88.98
# Exame 7 chega na atividade '2 - Avaliar prioridade' em 88.98
# Exame 6 inicia a atividade '3 - Agendar exame' em 88.98 (Tempo em fila = 3.97)
# Exame 7 inicia a atividade '2 - Avaliar prioridade' em 88.98 (Tempo em fila = 0.00)
# Exame 7 na atividade '2 - Avaliar prioridade' finalizado em 90.71
# Exame não urgente
# Exame 7 chega na atividade '3 - Agendar exame' em 90.71
# Exame 6 na atividade '3 - Agendar exame' finalizado em 93.05
# Exame 6 chega na atividade '8 - Avaliar se exame pode ser feito no hospital' em 93.05
# Exame 6 inicia a atividade '8 - Avaliar se exame pode ser feito no hospital' em 93.05
# Exame 7 inicia a atividade '3 - Agendar exame' em 93.05 (Tempo em fila = 2.34)
# Exame 5 na atividade '14 - Analisar exame não urgente' finalizado em 93.06
# Fim do processo do exame 5, no instante 93.06. Duração total = 23.61
# Exame 7 na atividade '3 - Agendar exame' finalizado em 96.14
# Reagendamento do exame 7 por paciente não estar preparado
# Exame 7 chega na atividade '3 - Agendar exame' em 96.14
# Exame 7 inicia a atividade '3 - Agendar exame' em 96.14 (Tempo em fila = 0.00)
# Exame 6 na atividade '8 - Avaliar se exame pode ser feito no hospital' finalizado em 97.01
# Exame 6 chega na atividade '10 - Realizar exame no hospital' em 97.01
# Exame 6 inicia a atividade '10 - Realizar exame no hospital' em 97.01 (Tempo em fila = 0.00)
# Exame 7 na atividade '3 - Agendar exame' finalizado em 98.14
# Exame 7 chega na atividade '8 - Avaliar se exame pode ser feito no hospital' em 98.14
# Exame 7 inicia a atividade '8 - Avaliar se exame pode ser feito no hospital' em 98.14
